# %%
import fix_yahoo_finance as yf
import datetime
from bokeh.plotting import figure, show, output_file
from pandas_datareader import data

# %%
start=datetime.datetime(2015,11,1)
end=datetime.datetime(2016,3,10)

# %%
yf.pdr_override()
df=data.get_data_yahoo(tickers="GOOG", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# c:\users\netot\desktop\cursos\python\aplications\web-based financial graph\virtual\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#
# c:\users\netot\desktop\cursos\python\aplications\web-based financial graph\virtual\lib\site-packages\fix_yahoo_finance\__init__.py:199: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   data = data.swapaxes(0, 2)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-11-02  711.059998  721.619995  705.849976  721.109985  721.109985
# 2015-11-03  718.859985  724.650024  714.719971  722.159973  722.159973
# 2015-11-04  722.000000  733.099976  721.900024  728.109985  728.109985
# 2015-11-05  729.469971  739.479980  729.469971  731.250000  731.250000
# 2015-11-06  731.500000  735.409973  727.010010  733.760010  733.760010
#
#              Volume
# Date
# 2015-11-02  1886300
# 2015-11-03  1565400
# 2015-11-04  1704600
# 2015-11-05  1861600
# 2015-11-06  1511600

# %%
# criando uma nova coluna pra armazenar se o dia teve fechamento peositivo ou negativo
def inc_dec(c, o):
    if c > o:
        value = "Increase"
    else:
        value = "Decrease"
    return value

df["Status"] = [inc_dec(c,o) for c, o in zip(df.Close, df.Open)]

# %%
# criando colunas aux para plotar os gráficos
df["Middle"] = (df.Open + df.Close)/2
df["Height"] = abs(df.Close - df.Open)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-11-02  711.059998  721.619995  705.849976  721.109985  721.109985
# 2015-11-03  718.859985  724.650024  714.719971  722.159973  722.159973
# 2015-11-04  722.000000  733.099976  721.900024  728.109985  728.109985
# 2015-11-05  729.469971  739.479980  729.469971  731.250000  731.250000
# 2015-11-06  731.500000  735.409973  727.010010  733.760010  733.760010
#
#              Volume    Status      Middle     Height
# Date
# 2015-11-02  1886300  Increase  716.084992  10.049987
# 2015-11-03  1565400  Increase  720.509979   3.299988
# 2015-11-04  1704600  Increase  725.054993   6.109985
# 2015-11-05  1861600  Increase  730.359985   1.780029
# 2015-11-06  1511600  Increase  732.630005   2.260010

# %%
date_increase = df.index[df.Close > df.Open]
date_decrease = df.index[df.Close < df.Open]

# %%
p = figure(x_axis_type = "datetime", width = 1000, height = 300)
p.title.text = "Candlestick Chart"

# %%
hours_12 = 12*60*60*1000

p.rect(df.index[df.Status == "Increase"], df.Middle[df.Status == "Increase"], hours_12, df.Height[df.Status == "Increase"], 
       fill_color = 'green', line_color = "black")
p.rect(df.index[df.Status == "Decrease"], df.Middle[df.Status == "Decrease"], hours_12, df.Height[df.Status == "Decrease"], 
       fill_color = 'red', line_color = "black")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='96532b1c-7742-4093-a175-84a045153900',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='d812baee-44ec-4eeb-b6e1-cf83280c58a4',
#         callback=None,
#         data={'height': {'__ndarray__': '...',
#           'shape': (47,),
#           'dtype': 'float64'},
#          'y': {'__ndarray__': '...',
#           'shape': (47,),
#           'dtype': 'float64'},
#          'x': {'__ndarray__': '...',
#           'shape': (47,),
#           'dtype': 'float64'}},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='0c14f204-c0b6-45ca-a8bf-47edb93334e4',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='1d448817-9ce1-40e2-a8a4-41507b506d31',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Rect(
#         id='d03d5792-79b7-4a28-a8f4-35c4ff87775e',
#         angle={'value': 0.0, 'units': 'rad'},
#         dilate=False,
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'red'},
#         height={'field': 'height', 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'black'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         width={'value': 43200000, 'units': 'data'},
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Rect(
#         id='5ab99012-c905-4851-8b0e-ae7ae39e4a35',
#         angle={'value': 0.0, 'units': 'rad'},
#         dilate=False,
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         height={'field': 'height', 'units': 'data'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width={'value': 1},
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         width={'value': 43200000, 'units': 'data'},
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='b8326eeb-758f-4112-aee8-71e15ae66f27',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='d812baee-44ec-4eeb-b6e1-cf83280c58a4',
#             callback=None,
#             data={'height': {'__ndarray__': '...',
#               'shape': (47,),
#               'dtype': 'float64'},
#              'y': {'__ndarray__': '...',
#               'shape': (47,),
#               'dtype': 'float64'},
#              'x': {'__ndarray__': '...',
#               'shape': (47,),
#               'dtype': 'float64'}},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='0c14f204-c0b6-45ca-a8bf-47edb93334e4',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='1d448817-9ce1-40e2-a8a4-41507b506d31',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
output_file("CS.html")
show(p)
